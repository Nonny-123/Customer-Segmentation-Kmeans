# %%
#Import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
#Load the csv file
df = pd.read_csv("CC GENERAL.csv")

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
#Checking for missing values
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#Filling the missing values with the median
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].median())

# %%
#Filling the missing values with the median
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].median())

# %%
#Dropping the unnecessary columns
df = df.drop(columns=['CUST_ID'], axis=1)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#Scale the dataset
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)

# %%
#Apply PCA(Dimentionality reduction)
pca = PCA(n_components=2)
pca_componenets = pca.fit_transform(scaled_df)

# %%
#Elbow method
inertia = []
for k in range(2, 10):
    model = KMeans(n_clusters=k,random_state=30)
    model.fit(scaled_df)
    inertia.append(model.inertia_)

# %%
#Plot the elbow method visualization
plt.plot(range(2, 10), inertia)
plt.xlabel("k")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.show()

# %%
#Silhouette score
for k in range(2, 10):
    model = KMeans(n_clusters=k, random_state=30)
    preds = model.fit_predict(scaled_df)
    print(f"k = {k}, Silhouette: {silhouette_score(scaled_df, preds):.4f}")
# Out:
# k = 2, Silhouette: 0.2568
# k = 3, Silhouette: 0.2510
# k = 4, Silhouette: 0.1977
# k = 5, Silhouette: 0.2097
# k = 6, Silhouette: 0.2035
# k = 7, Silhouette: 0.2017
# k = 8, Silhouette: 0.2133
# k = 9, Silhouette: 0.2047

# %%
kmeans = KMeans(n_clusters=4, random_state=30)
clusters = kmeans.fit_predict(scaled_df)

df['Cluster'] = clusters

#Cluster profiling
df.groupby('Cluster').mean()
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0        1012.658327           0.789924   270.041785        209.937299
# 1        3551.153761           0.986879  7681.620098       5095.878826
# 2        4602.449658           0.968389   501.862982        320.188797
# 3         894.907458           0.934734  1236.178934        593.974874
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                     60.371441    596.509903             0.170145
# 1                   2587.208264    653.638891             0.946418
# 2                    181.759123   4521.509581             0.287832
# 3                    642.478274    210.570626             0.885165
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                          0.086301                          0.080558
# 1                          0.739031                          0.788060
# ...

# %%
#Visualize clusters
df_pca = pd.DataFrame(pca_componenets, columns=['PCA1', 'PCA2'])
df_pca['Cluster'] = clusters

sns.scatterplot(data=df_pca, x='PCA1', y='PCA2', hue='Cluster')
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 0    3977
# 3    3367
# 2    1197
# 1     409
# Name: count, dtype: int64

# %% [raw]
# CLUSTER INTERPRETATIONS AND LABELS
#
# ⸻
#
# Cluster 0: Low-Value Inactive Users
# 	•	Size: 3977 (largest segment)
# 	•	Balance: Low (USD 1,013)
# 	•	Spending: Very low purchases
# 	•	Transactions: ~3 purchases total
# 	•	Cash Advances: Low
# 	•	Full Payment %: 7.8% → low likelihood of paying in full
#
# Label: “Low Activity, Low Engagement Customers”
#
# Business Insight:
# These customers are probably inactive or barely using their credit cards. Might be churn risks.
# Consider:
# 	•	Re-engagement emails
# 	•	Low-limit upsell offers
# 	•	Personalized usage incentives (e.g., cashback for spending USD X this month)
#
# ⸻
#
# Cluster 1: Premium Full-Payment High Spenders
# 	•	Size: 409 (smallest segment)
# 	•	Balance: Very high (USD 3,551)
# 	•	Spending: Huge one-off purchases (USD 5,096)
# 	•	Frequency: Very active
# 	•	Full Payment %: High (28.6%)
# 	•	Payments: USD 7,289+
#
# Label: “High-Value, Low-Risk Customers”
#
# Business Insight:
# These are your best customers. They:
# 	•	Spend a lot
# 	•	Pay off their balances
# 	•	Rarely use cash advances
#
# Focus on:
# 	•	Retention (loyalty perks, travel rewards)
# 	•	Priority support
# 	•	Premium card upgrades or personalized offers
#
# ⸻
#
# Cluster 2: Cash-Advance-Heavy, Low Full-Payment Users
# 	•	Size: 1197
# 	•	Balance: Highest (₦4,602)
# 	•	Spending: Low
# 	•	Cash Advances: Extremely high (₦4,521 avg), 14 cash advance transactions per user
# 	•	Full Payment %: Very low (3.4%)
#
# Label: “High-Risk, Credit-Dependent Users”
#
# Business Insight:
# These users don’t purchase much, but take lots of cash advances and barely repay in full.
#
# They pose credit risk. Consider:
# 	•	Monitoring for delinquency or overuse
# 	•	Setting cash advance limits
# 	•	Offering financial education or repayment plans
#
# ⸻
#
# Cluster 3: Installment-Focused, High Frequency Users
# 	•	Size: 3367
# 	•	Spending: Medium (₦1,236)
# 	•	Style: Mix of one-off and installment purchases
# 	•	Frequency: High
# 	•	Full Payment %: Moderate (unknown in your data)
#
# Label: “Engaged Installment Shoppers”
#
# Business Insight:
# These customers are active and engaged, prefer installments, and have good usage behavior.
#
# They’re great targets for:
# 	•	Installment-based product recommendations
# 	•	EMI (equated monthly installment) plans
# 	•	Loyalty programs

# %%
import joblib

#Save scaler
joblib.dump(scaler, "kmeans_scaler.pkl")

#Save Kmeans model
joblib.dump(kmeans, "kmeans_model.pkl")
# Out:
# ['kmeans_model.pkl']
